# %%
# %reset -f
import pandas as pd
import scipy.io as sio

# %%
nucleus=['ACC','AMY','CAU','HIP','GP','PUT','THA']
currMat = sio.loadmat(rf'D:\research\HCP_parcellation_Lsym-AVR\CamCan\KRR parcel size to age\weights\All nets PFM nuc by net.mat')
currMat = currMat['posMatNucByNet']
split_arrays = [currMat[i] for i in range(currMat.shape[0])]
for i in range(7):
    df = pd.DataFrame(split_arrays[i].T,columns=['VIS','SMN','DAN','VAN','LIM','FPN','DMN'])
    df.to_csv(f'ANOVA/NucleusWeightsPositive/{nucleus[i]}.csv',index=False)

# %%
nucleus=['ACC','AMY','CAU','HIP','GP','PUT','THA']
currMat = sio.loadmat(rf'D:\research\HCP_parcellation_Lsym-AVR\CamCan\KRR parcel size to age\weights\All nets PFM nuc by net.mat')
currMat = currMat['negMatNucByNet']
split_arrays = [currMat[i] for i in range(currMat.shape[0])]
for i in range(7):
    df = pd.DataFrame(split_arrays[i].T,columns=['VIS','SMN','DAN','VAN','LIM','FPN','DMN'])
    df.to_csv(f'ANOVA/NucleusWeightsNegative/{nucleus[i]}.csv',index=False)
